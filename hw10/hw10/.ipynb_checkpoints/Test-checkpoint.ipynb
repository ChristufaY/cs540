# %%
import gym
import random
import numpy as np
import time
from collections import deque
import pickle


from collections import defaultdict


EPISODES =  20000
LEARNING_RATE = .1
DISCOUNT_FACTOR = .99
EPSILON = 1
EPSILON_DECAY = .999


def default_Q_value():
    return 0

if __name__ == "__main__":

    random.seed(1)
    np.random.seed(1)
    env = gym.envs.make("FrozenLake-v1")
    env.seed(1)
    env.action_space.np_random.seed(1)


    # You will need to update the Q_table in your iteration
    Q_table = defaultdict(default_Q_value) # starts with a pessimistic estimate of zero reward for each state.
    episode_reward_record = deque(maxlen=100)

    for i in range(EPISODES):
        episode_reward = 0
        done = False
        obs = env.reset()

        ##########################################################
        # YOU DO NOT NEED TO CHANGE ANYTHING ABOVE THIS LINE
        # TODO: Replace the following with Q-Learning
        # while the state is not a terminal state, keep iterating
        while (not done):
            # Epsilon greedy algorithm condition where
            # agent chooses random action
            if (random.uniform(0,1) < EPSILON):
                action = env.action_space.sample()
            # Epsilon greedy algorithm condition where
            # agent chooses optimal policy action
            else:
                # find the optimal action
                prediction = np.array([Q_table[(obs,i)] for i in range(env.action_space.n)])
                action =  np.argmax(prediction)
            # get the rewards, state, terminal boolean, and info
            new_obs,reward,done,info = env.step(action)
            episode_reward += reward # update episode reward
            EPSILON = EPSILON * EPSILON_DECAY
            # update the Q_table with values of newly updated state   
            best_next_action = np.argmax([Q_table[new_obs, i] for i in range(env.action_space.n)])
            td_target = reward + DISCOUNT_FACTOR * Q_table[(new_obs, best_next_action)]
            td_delta = td_target - Q_table[(obs, action)]
            Q_table[(obs, action)] += LEARNING_RATE * td_delta

        # END of TODO
        # YOU DO NOT NEED TO CHANGE ANYTHING BELOW THIS LINE
        ##########################################################

        # record the reward for this episode
        episode_reward_record.append(episode_reward) 

        
        if i%100 ==0 and i>0:
            print("LAST 100 EPISODE AVERAGE REWARD: " + str(sum(list(episode_reward_record))/100))
            print("EPSILON: " + str(EPSILON) )
    
    
    #### DO NOT MODIFY ######
    model_file = open('Q_TABLE.pkl' ,'wb')
    pickle.dump([Q_table,EPSILON],model_file)
    model_file.close()
    #########################
# Out:
# LAST 100 EPISODE AVERAGE REWARD: 0.02
# EPSILON: 0.4354323744883354
# LAST 100 EPISODE AVERAGE REWARD: 0.03
# EPSILON: 0.19362711688165665
# LAST 100 EPISODE AVERAGE REWARD: 0.02
# EPSILON: 0.06651316349089494
# LAST 100 EPISODE AVERAGE REWARD: 0.02
# EPSILON: 0.024727229501382137
# LAST 100 EPISODE AVERAGE REWARD: 0.02
# EPSILON: 0.01199564064508013
# LAST 100 EPISODE AVERAGE REWARD: 0.03
# EPSILON: 0.007215915948439084
# LAST 100 EPISODE AVERAGE REWARD: 0.0
# EPSILON: 0.0037023043098631577
# LAST 100 EPISODE AVERAGE REWARD: 0.03
# EPSILON: 0.002124800099461557
# LAST 100 EPISODE AVERAGE REWARD: 0.01
# EPSILON: 0.0005060905104675637
# LAST 100 EPISODE AVERAGE REWARD: 0.03
# EPSILON: 0.0002638523880429118
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 0.00015234003998747017
# LAST 100 EPISODE AVERAGE REWARD: 0.03
# EPSILON: 9.000380542784409e-05
# LAST 100 EPISODE AVERAGE REWARD: 0.03
# EPSILON: 5.365599896486092e-05
# LAST 100 EPISODE AVERAGE REWARD: 0.06
# EPSILON: 3.125949279113543e-05
# LAST 100 EPISODE AVERAGE REWARD: 0.03
# EPSILON: 1.9012077470776536e-05
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 1.184419383521734e-05
# LAST 100 EPISODE AVERAGE REWARD: 0.01
# EPSILON: 6.914140043290681e-06
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 4.146700367684632e-06
# LAST 100 EPISODE AVERAGE REWARD: 0.02
# EPSILON: 2.65671468179796e-06
# LAST 100 EPISODE AVERAGE REWARD: 0.01
# EPSILON: 7.389317999510855e-07
# LAST 100 EPISODE AVERAGE REWARD: 0.0
# EPSILON: 3.541915556951527e-07
# LAST 100 EPISODE AVERAGE REWARD: 0.06
# EPSILON: 7.116743566200317e-08
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 4.166942602452664e-08
# LAST 100 EPISODE AVERAGE REWARD: 0.01
# EPSILON: 2.5881528067898758e-08
# LAST 100 EPISODE AVERAGE REWARD: 0.07
# EPSILON: 1.59153865703153e-08
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 9.650755315565663e-09
# LAST 100 EPISODE AVERAGE REWARD: 0.02
# EPSILON: 5.96432281604987e-09
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 3.4161590565739365e-09
# LAST 100 EPISODE AVERAGE REWARD: 0.06
# EPSILON: 2.0797936282716956e-09
# LAST 100 EPISODE AVERAGE REWARD: 0.06
# EPSILON: 1.2510891627837242e-09
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 7.369389881236615e-10
# LAST 100 EPISODE AVERAGE REWARD: 0.01
# EPSILON: 4.54984769098809e-10
# LAST 100 EPISODE AVERAGE REWARD: 0.07
# EPSILON: 2.621687184559949e-10
# LAST 100 EPISODE AVERAGE REWARD: 0.09
# EPSILON: 1.4762880790069466e-10
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 9.224664482668865e-11
# LAST 100 EPISODE AVERAGE REWARD: 0.05
# EPSILON: 5.3100679654125776e-11
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 3.281707854493393e-11
# LAST 100 EPISODE AVERAGE REWARD: 0.03
# EPSILON: 1.9427447629863803e-11
# LAST 100 EPISODE AVERAGE REWARD: 0.02
# EPSILON: 1.1466425191729843e-11
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 6.849430737684976e-12
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 4.116119600626991e-12
# LAST 100 EPISODE AVERAGE REWARD: 0.05
# EPSILON: 2.441590572513716e-12
# LAST 100 EPISODE AVERAGE REWARD: 0.05
# EPSILON: 1.4984114867365936e-12
# LAST 100 EPISODE AVERAGE REWARD: 0.01
# EPSILON: 9.533047825490495e-13
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 5.520626212772381e-13
# LAST 100 EPISODE AVERAGE REWARD: 0.05
# EPSILON: 3.2518583135970666e-13
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 1.8165433329555608e-13
# LAST 100 EPISODE AVERAGE REWARD: 0.06
# EPSILON: 1.0509155589278015e-13
# LAST 100 EPISODE AVERAGE REWARD: 0.02
# EPSILON: 6.055525459352975e-14
# LAST 100 EPISODE AVERAGE REWARD: 0.03
# EPSILON: 3.4099034012962876e-14
# LAST 100 EPISODE AVERAGE REWARD: 0.06
# EPSILON: 2.0594352499434342e-14
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 1.211872419785648e-14
# LAST 100 EPISODE AVERAGE REWARD: 0.05
# EPSILON: 7.025026792518788e-15
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 4.084534826605674e-15
# LAST 100 EPISODE AVERAGE REWARD: 0.06
# EPSILON: 2.4693530185016735e-15
# LAST 100 EPISODE AVERAGE REWARD: 0.03
# EPSILON: 1.4016820667708978e-15
# LAST 100 EPISODE AVERAGE REWARD: 0.1
# EPSILON: 7.988291420797208e-16
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 4.956690291623529e-16
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 2.905109432407197e-16
# LAST 100 EPISODE AVERAGE REWARD: 0.05
# EPSILON: 1.759835595137024e-16
# LAST 100 EPISODE AVERAGE REWARD: 0.03
# EPSILON: 1.0449402628394973e-16
# LAST 100 EPISODE AVERAGE REWARD: 0.09
# EPSILON: 6.039194422094223e-17
# LAST 100 EPISODE AVERAGE REWARD: 0.08
# EPSILON: 3.521901171779569e-17
# LAST 100 EPISODE AVERAGE REWARD: 0.03
# EPSILON: 2.1678985487742152e-17
# LAST 100 EPISODE AVERAGE REWARD: 0.11
# EPSILON: 1.2404560589776017e-17
# LAST 100 EPISODE AVERAGE REWARD: 0.01
# EPSILON: 7.454437738865209e-18
# LAST 100 EPISODE AVERAGE REWARD: 0.06
# EPSILON: 4.291058077145198e-18
# LAST 100 EPISODE AVERAGE REWARD: 0.02
# EPSILON: 2.646642033850136e-18
# LAST 100 EPISODE AVERAGE REWARD: 0.05
# EPSILON: 1.4948202850709765e-18
# LAST 100 EPISODE AVERAGE REWARD: 0.09
# EPSILON: 8.858074425146771e-19
# LAST 100 EPISODE AVERAGE REWARD: 0.09
# EPSILON: 5.270207493516181e-19
# LAST 100 EPISODE AVERAGE REWARD: 0.05
# EPSILON: 3.0489462889402777e-19
# LAST 100 EPISODE AVERAGE REWARD: 0.05
# EPSILON: 1.8249258950598322e-19
# LAST 100 EPISODE AVERAGE REWARD: 0.05
# EPSILON: 1.0706572400737486e-19
# LAST 100 EPISODE AVERAGE REWARD: 0.02
# EPSILON: 6.369991421166608e-20
# LAST 100 EPISODE AVERAGE REWARD: 0.07
# EPSILON: 3.69997640162877e-20
# LAST 100 EPISODE AVERAGE REWARD: 0.05
# EPSILON: 2.1107551079870565e-20
# LAST 100 EPISODE AVERAGE REWARD: 0.07
# EPSILON: 1.2395886331102828e-20
# LAST 100 EPISODE AVERAGE REWARD: 0.05
# EPSILON: 7.207293426973686e-21
# LAST 100 EPISODE AVERAGE REWARD: 0.06
# EPSILON: 4.2199606814368064e-21
# LAST 100 EPISODE AVERAGE REWARD: 0.05
# EPSILON: 2.5975875502913406e-21
# LAST 100 EPISODE AVERAGE REWARD: 0.03
# EPSILON: 1.4907889312381081e-21
# LAST 100 EPISODE AVERAGE REWARD: 0.02
# EPSILON: 9.085165256786579e-22
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 5.642937329077165e-22
# LAST 100 EPISODE AVERAGE REWARD: 0.03
# EPSILON: 3.3439176158243707e-22
# LAST 100 EPISODE AVERAGE REWARD: 0.05
# EPSILON: 1.9974780037489975e-22
# LAST 100 EPISODE AVERAGE REWARD: 0.06
# EPSILON: 1.1169421105268977e-22
# LAST 100 EPISODE AVERAGE REWARD: 0.01
# EPSILON: 6.685380415447657e-23
# LAST 100 EPISODE AVERAGE REWARD: 0.03
# EPSILON: 3.8138623950495684e-23
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 2.3149608157716778e-23
# LAST 100 EPISODE AVERAGE REWARD: 0.09
# EPSILON: 1.2918832877009558e-23
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 7.541468921415433e-24
# LAST 100 EPISODE AVERAGE REWARD: 0.02
# EPSILON: 4.559282717760414e-24
# LAST 100 EPISODE AVERAGE REWARD: 0.05
# EPSILON: 2.696359789663986e-24
# LAST 100 EPISODE AVERAGE REWARD: 0.03
# EPSILON: 1.6284855445620806e-24
# LAST 100 EPISODE AVERAGE REWARD: 0.09
# EPSILON: 8.907858467323039e-25
# LAST 100 EPISODE AVERAGE REWARD: 0.06
# EPSILON: 5.35847645679161e-25
# LAST 100 EPISODE AVERAGE REWARD: 0.03
# EPSILON: 3.1912749849437584e-25
# LAST 100 EPISODE AVERAGE REWARD: 0.06
# EPSILON: 1.8499300673490278e-25
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 1.0809920213320584e-25
# LAST 100 EPISODE AVERAGE REWARD: 0.06
# EPSILON: 6.191550654871212e-26
# LAST 100 EPISODE AVERAGE REWARD: 0.05
# EPSILON: 3.680046513109919e-26
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 2.35773813735607e-26
# LAST 100 EPISODE AVERAGE REWARD: 0.03
# EPSILON: 1.3971592508001943e-26
# LAST 100 EPISODE AVERAGE REWARD: 0.02
# EPSILON: 8.320871432420339e-27
# LAST 100 EPISODE AVERAGE REWARD: 0.1
# EPSILON: 4.709031681088242e-27
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 2.7106978605930914e-27
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 1.663563439796244e-27
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 1.0499387179799545e-27
# LAST 100 EPISODE AVERAGE REWARD: 0.09
# EPSILON: 6.221774883974121e-28
# LAST 100 EPISODE AVERAGE REWARD: 0.03
# EPSILON: 3.87218156092147e-28
# LAST 100 EPISODE AVERAGE REWARD: 0.02
# EPSILON: 2.2468873930150493e-28
# LAST 100 EPISODE AVERAGE REWARD: 0.05
# EPSILON: 1.3394876701121982e-28
# LAST 100 EPISODE AVERAGE REWARD: 0.03
# EPSILON: 7.430384459696324e-29
# LAST 100 EPISODE AVERAGE REWARD: 0.07
# EPSILON: 4.346232695393778e-29
# LAST 100 EPISODE AVERAGE REWARD: 0.03
# EPSILON: 2.5780885408208016e-29
# LAST 100 EPISODE AVERAGE REWARD: 0.09
# EPSILON: 1.428683015708809e-29
# LAST 100 EPISODE AVERAGE REWARD: 0.05
# EPSILON: 8.331707899182981e-30
# LAST 100 EPISODE AVERAGE REWARD: 0.1
# EPSILON: 4.776892734608684e-30
# LAST 100 EPISODE AVERAGE REWARD: 0.06
# EPSILON: 2.719664675921399e-30
# LAST 100 EPISODE AVERAGE REWARD: 0.05
# EPSILON: 1.6035892781715956e-30
# LAST 100 EPISODE AVERAGE REWARD: 0.03
# EPSILON: 9.569407932606677e-31
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 5.64238676004401e-31
# LAST 100 EPISODE AVERAGE REWARD: 0.15
# EPSILON: 3.0373865370441864e-31
# LAST 100 EPISODE AVERAGE REWARD: 0.09
# EPSILON: 1.7431952308245619e-31
# LAST 100 EPISODE AVERAGE REWARD: 0.01
# EPSILON: 1.0257813265050176e-31
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 5.946287071404621e-32
# LAST 100 EPISODE AVERAGE REWARD: 0.02
# EPSILON: 3.6456050275500336e-32
# LAST 100 EPISODE AVERAGE REWARD: 0.02
# EPSILON: 2.206199104344575e-32
# LAST 100 EPISODE AVERAGE REWARD: 0.06
# EPSILON: 1.3126020954280697e-32
# LAST 100 EPISODE AVERAGE REWARD: 0.01
# EPSILON: 7.458198551114383e-33
# LAST 100 EPISODE AVERAGE REWARD: 0.02
# EPSILON: 4.477472592814852e-33
# LAST 100 EPISODE AVERAGE REWARD: 0.07
# EPSILON: 2.4369677255144445e-33
# LAST 100 EPISODE AVERAGE REWARD: 0.08
# EPSILON: 1.5030747898368397e-33
# LAST 100 EPISODE AVERAGE REWARD: 0.07
# EPSILON: 8.164477726059343e-34
# LAST 100 EPISODE AVERAGE REWARD: 0.06
# EPSILON: 4.588276976744938e-34
# LAST 100 EPISODE AVERAGE REWARD: 0.08
# EPSILON: 2.7243882117789364e-34
# LAST 100 EPISODE AVERAGE REWARD: 0.02
# EPSILON: 1.6619585041121256e-34
# LAST 100 EPISODE AVERAGE REWARD: 0.03
# EPSILON: 1.048925781488136e-34
# LAST 100 EPISODE AVERAGE REWARD: 0.02
# EPSILON: 6.27827334176782e-35
# LAST 100 EPISODE AVERAGE REWARD: 0.05
# EPSILON: 3.6796874590335326e-35
# LAST 100 EPISODE AVERAGE REWARD: 0.03
# EPSILON: 2.255977039012455e-35
# LAST 100 EPISODE AVERAGE REWARD: 0.07
# EPSILON: 1.285698265925251e-35
# LAST 100 EPISODE AVERAGE REWARD: 0.05
# EPSILON: 7.467911538674026e-36
# LAST 100 EPISODE AVERAGE REWARD: 0.05
# EPSILON: 4.4743415866666484e-36
# LAST 100 EPISODE AVERAGE REWARD: 0.05
# EPSILON: 2.3774845062837892e-36
# LAST 100 EPISODE AVERAGE REWARD: 0.07
# EPSILON: 1.4201824180961931e-36
# LAST 100 EPISODE AVERAGE REWARD: 0.01
# EPSILON: 8.733159852489789e-37
# LAST 100 EPISODE AVERAGE REWARD: 0.02
# EPSILON: 5.22194577474134e-37
# LAST 100 EPISODE AVERAGE REWARD: 0.03
# EPSILON: 3.0913500702346068e-37
# LAST 100 EPISODE AVERAGE REWARD: 0.08
# EPSILON: 1.751239323149339e-37
# LAST 100 EPISODE AVERAGE REWARD: 0.05
# EPSILON: 1.0608527383177405e-37
# LAST 100 EPISODE AVERAGE REWARD: 0.07
# EPSILON: 6.2238673252796e-38
# LAST 100 EPISODE AVERAGE REWARD: 0.09
# EPSILON: 3.7815814830436497e-38
# LAST 100 EPISODE AVERAGE REWARD: 0.03
# EPSILON: 2.3045712230317253e-38
# LAST 100 EPISODE AVERAGE REWARD: 0.03
# EPSILON: 1.3372596160245704e-38
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 7.790751851320952e-39
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 4.672441310725431e-39
# LAST 100 EPISODE AVERAGE REWARD: 0.05
# EPSILON: 2.919599773195816e-39
# LAST 100 EPISODE AVERAGE REWARD: 0.07
# EPSILON: 1.6276778189687703e-39
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 9.635722309348688e-40
# LAST 100 EPISODE AVERAGE REWARD: 0.05
# EPSILON: 5.6644601211045496e-40
# LAST 100 EPISODE AVERAGE REWARD: 0.01
# EPSILON: 3.296762441919411e-40
# LAST 100 EPISODE AVERAGE REWARD: 0.03
# EPSILON: 1.9536105687222594e-40
# LAST 100 EPISODE AVERAGE REWARD: 0.01
# EPSILON: 1.1530557110133134e-40
# LAST 100 EPISODE AVERAGE REWARD: 0.06
# EPSILON: 6.551656791641096e-41
# LAST 100 EPISODE AVERAGE REWARD: 0.05
# EPSILON: 3.718925469009394e-41
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 2.083699836228371e-41
# LAST 100 EPISODE AVERAGE REWARD: 0.07
# EPSILON: 1.2298367108916898e-41
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 7.570232924577419e-42
# LAST 100 EPISODE AVERAGE REWARD: 0.09
# EPSILON: 4.331633186651393e-42
# LAST 100 EPISODE AVERAGE REWARD: 0.06
# EPSILON: 2.55916612958898e-42
# LAST 100 EPISODE AVERAGE REWARD: 0.05
# EPSILON: 1.5487223602943362e-42
# LAST 100 EPISODE AVERAGE REWARD: 0.05
# EPSILON: 9.260501722387218e-43
# LAST 100 EPISODE AVERAGE REWARD: 0.09
# EPSILON: 5.553912078253348e-43
# LAST 100 EPISODE AVERAGE REWARD: 0.05
# EPSILON: 3.0624181835247046e-43
# LAST 100 EPISODE AVERAGE REWARD: 0.03
# EPSILON: 1.8458718090850497e-43
# LAST 100 EPISODE AVERAGE REWARD: 0.07
# EPSILON: 1.0883769121004458e-43
# LAST 100 EPISODE AVERAGE REWARD: 0.07
# EPSILON: 6.520926305245876e-44
# LAST 100 EPISODE AVERAGE REWARD: 0.05
# EPSILON: 3.864200339643015e-44
# LAST 100 EPISODE AVERAGE REWARD: 0.05
# EPSILON: 2.1846804541170302e-44
# LAST 100 EPISODE AVERAGE REWARD: 0.1
# EPSILON: 1.298499541646727e-44
# LAST 100 EPISODE AVERAGE REWARD: 0.07
# EPSILON: 7.93710284748754e-45
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 4.527942494600229e-45
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 2.640578339246959e-45
# LAST 100 EPISODE AVERAGE REWARD: 0.03
# EPSILON: 1.5569577935390175e-45
# LAST 100 EPISODE AVERAGE REWARD: 0.05
# EPSILON: 9.061622586535667e-46
# LAST 100 EPISODE AVERAGE REWARD: 0.06
# EPSILON: 5.418348292865616e-46
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 3.2691772819985732e-46
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 2.018384011111107e-46
# LAST 100 EPISODE AVERAGE REWARD: 0.05
# EPSILON: 1.166517732642735e-46
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 6.654726937310293e-47
# LAST 100 EPISODE AVERAGE REWARD: 0.05
# EPSILON: 4.1540832354683654e-47
# LAST 100 EPISODE AVERAGE REWARD: 0.05
# EPSILON: 2.4616456463384225e-47
# LAST 100 EPISODE AVERAGE REWARD: 0.06
# EPSILON: 1.4807902807679016e-47
# LAST 100 EPISODE AVERAGE REWARD: 0.04
# EPSILON: 8.827769158689233e-48
# LAST 100 EPISODE AVERAGE REWARD: 0.08
# EPSILON: 5.1121965094364674e-48
# LAST 100 EPISODE AVERAGE REWARD: 0.06
# EPSILON: 3.038515226243549e-48
# LAST 100 EPISODE AVERAGE REWARD: 0.07
# EPSILON: 1.7755323697031073e-48
